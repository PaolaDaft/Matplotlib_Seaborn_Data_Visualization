# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
data = np.random.randint(1, 50, 100) # un arreglo de 100 elementos aleatorios entre 1 y 50
data
# Out:
# array([ 9, 12, 41, 26, 20, 48, 21, 21,  3, 35, 14, 33, 21, 49, 49, 12, 49,
#         3, 31, 22, 40,  4,  4, 48,  5, 15, 31, 30, 29,  5, 19, 26, 27,  6,
#        31, 27, 13, 25,  8, 18, 37, 34, 15, 26, 15, 49, 28, 16, 26, 29, 29,
#        37, 48, 36, 10, 16,  9, 22, 42, 28, 20, 38,  7, 46, 17, 35,  1, 37,
#         8, 24, 15,  3, 31, 47,  9, 30, 47, 28,  7, 31, 45, 39, 11, 17, 46,
#         5, 15, 27,  3, 47, 19, 34, 38, 32,  3, 47, 49, 18, 21, 17])

# %% [markdown]
# ## Histograma
# Muestra la distribución de los datos

# %%
plt.hist(data, bins=10, alpha=0.5, color='b', edgecolor='black') # Bins es el número de barras, alpha es la transparencia, edgecolor es el color de los bordes
plt.show()

# %%
plt.hist(data, bins=10, histtype='step', edgecolor='magenta') 
plt.show()

# %% [markdown]
# ## Boxplot

# %%
plt.boxplot(data, vert=False, patch_artist=True, notch=True ) # vert es para que la gráfica sea horizontal, patch_artist es para que se rellene el cuadro y notch es para que tenga una muesca (Enfocado en la mediana)
plt.show()

# %%
data = np.append(data, [100, 200, 300, 400]) # Agregamos 4 valores atípicos
plt.boxplot(data, vert=False, patch_artist=True, notch=True ) # vert es para que la gráfica sea horizontal, patch_artist es para que se rellene el cuadro y notch es para que tenga una muesca (Enfocado en la mediana)
# Se puede observar que los valores atípicos se representan como puntos
# Si agrego el atributo showfliers=False, los valores atípicos no se mostrarán
plt.show()

# %% [markdown]
# ## Scatterplot
# Gráfica de dispersion

# %%
N = 50
x = np.random.rand(N) # Genera un arreglo de N elementos aleatorios entre 0 y 1
y = np.random.rand(N)
colors = np.random.rand(N)
area = (30 * np.random.rand(N))**2

# %%
plt.scatter(x, y, s=area, c=colors, alpha=0.5) # s es el tamaño de los puntos, c es el color de los puntos
# El atributo mareker es para cambiar la forma de los puntos (marker='x'), (marker='o'), (marker='^')
plt.show()
