# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.barplot(x=['A','B','C'], y =[1, 2, 3])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ### Comando set

# %%
sns.set(style='darkgrid', palette='dark', font="serif", font_scale=1) # Algunos otros style podrían ser "white, dark, whitegrid, ticks"
sns.barplot(x=['A','B','C'], y =[1, 2, 3])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
